# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4]
y = [5,6,7,8]

plt.plot(x,y)
plt.show()

# %%
x = [1,2,3,4,9]
y = [5,6,7,8,1]
c = "r"
plt.plot(x,y,c)
plt.show()

# %%
x = [1,2,3,4,9]
y = [50,6,7,18,1]
c = "r"
plt.plot(x,y,c)
plt.show()

# %% [markdown]
# BAR GRAPH

# %%
x = ["car","bike","scooter","bicycle"]
y = [40,85,75,35]


plt.title("VEHICLES IN SOCIETY")
plt.bar(x,y)
plt.show()

# %%
x = ["car","bike","scooter","bicycle"]
y = [40,85,75,35]


plt.title("PARKING SURVEY")
plt.xlabel("vehicles",fontsize = 15)
plt.ylabel("numbers of vehicles",fontsize = 15)
plt.bar(x,y)
plt.show()

# %%
x = ["car","bike","scooter","bicycle"]
y = [40,85,75,35]


plt.title("PARKING SURVEY")
plt.xlabel("vehicles")
plt.ylabel("numbers of vehicles")
plt.bar(x,y,width = 0.4)
plt.show()

# %%
x = ["car","bike","scooter","bicycle"]
y = [40,85,75,35]


plt.title("PARKING SURVEY")
plt.xlabel("vehicles")
plt.ylabel("numbers of vehicles")

plt.bar(x,y,width = 0.4,color = "y")
plt.show()

# %%
x = ["car","bike","scooter","bicycle"]
y = [40,85,75,35]


plt.title("PARKING SURVEY")
plt.xlabel("vehicles")
plt.ylabel("numbers of vehicles")

c = ["red","yellow","green","blue"]

plt.bar(x,y,width = 0.4,color = c)
plt.show()

# %%
x = ["car","bike","scooter","bicycle"]
y = [40,85,75,35]


plt.title("PARKING SURVEY")
plt.xlabel("vehicles")
plt.ylabel("numbers of vehicles")

c = ["red","yellow","green","blue"]

plt.bar(x,y,width = 0.4,color = c, align = "edge")
plt.show()

# %%
x = ["car","bike","scooter","bicycle"]
y = [40,85,75,35]


plt.title("PARKING SURVEY")
plt.xlabel("vehicles")
plt.ylabel("numbers of vehicles")

c = ["red","yellow","green","blue"]

plt.bar(x,y,width = 0.4,color = c, align = "center")
plt.show()

# %%
x = ["car","bike","scooter","bicycle"]
y = [40,85,75,35]


plt.title("PARKING SURVEY")
plt.xlabel("vehicles")
plt.ylabel("numbers of vehicles")

c = ["red","yellow","green","blue"]

plt.bar(x,y,width = 0.4,color = c, edgecolor = "black",linewidth =  5)
plt.show()

# %%
x = ["car","bike","scooter","bicycle"]
y = [40,85,75,35]


plt.title("PARKING SURVEY")
plt.xlabel("vehicles")
plt.ylabel("numbers of vehicles")

c = ["red","yellow","green","blue"]

plt.bar(x,y,width = 0.4,color = c, edgecolor = "black",linewidth =  5,linestyle = ":", alpha = 0.4 )
plt.show()

# %%
x = ["car","bike","scooter","bicycle"]
y = [40,85,75,35]


plt.title("PARKING SURVEY")
plt.xlabel("vehicles")
plt.ylabel("numbers of vehicles")

c = ["red","yellow","green","blue"]

plt.bar(x,y,width = 0.4,color = c, edgecolor = "black")
plt.legend("Transport")
plt.show()

# %%
x = ["car","bike","scooter","bicycle"]
y = [40,85,75,35]
z = [20,30,40,15]

plt.title("PARKING SURVEY")
plt.xlabel("vehicles")
plt.ylabel("numbers of vehicles")

plt.bar(x,y,width = 0.4,color = "r",edgecolor = "black")
plt.bar(x,z,width = 0.4,color = "g",edgecolor = "black")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


x = ["car","bike","scooter","bicycle"]
y = [40,85,75,35]
z = [20,30,40,15]

width = 0.2
p = np.arange(len(x))
p1 = [j + width for j in p]

plt.title("PARKING SURVEY")
plt.xlabel("vehicles")
plt.ylabel("numbers of vehicles")

plt.bar(p,y,width = 0.2,color = "r",edgecolor = "black")
plt.bar(p1,z,width = 0.2,color = "g",edgecolor = "black")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


x = ["car","bike","scooter","bicycle"]
y = [40,85,75,35]
z = [20,30,40,15]

width = 0.2
p = np.arange(len(x))
p1 = [j + width for j in p]
plt.title("PARKING SURVEY")
plt.xlabel("vehicles")
plt.ylabel("numbers of vehicles")

plt.xticks(p+width,x)

plt.bar(p,y,width = 0.2,color = "r",edgecolor = "black")
plt.bar(p1,z,width = 0.2,color = "g",edgecolor = "black")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


x = ["car","bike","scooter","bicycle"]
y = [40,85,75,35]
z = [20,30,40,15]

width = 0.2
p = np.arange(len(x))
p1 = [j + width for j in p]
plt.title("PARKING SURVEY")
plt.xlabel("vehicles")
plt.ylabel("numbers of vehicles")

plt.xticks(p+width/2, x, rotation = 30)

plt.bar(p,y,width = 0.2,color = "r",edgecolor = "black")
plt.bar(p1,z,width = 0.2,color = "g",edgecolor = "black")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


x = ["car","bike","scooter","bicycle"]
y = [40,85,75,35]
z = [20,30,40,15]

width = 0.2
p = np.arange(len(x))
p1 = [j + width for j in p]
plt.title("PARKING SURVEY")
plt.xlabel("vehicles")
plt.ylabel("numbers of vehicles")

plt.xticks(p+width/2, x, rotation = 30)

plt.barh(p,y,color = "r",edgecolor = "black")
plt.bar(p1,z,color = "g",edgecolor = "black")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


x = ["car","bike","scooter","bicycle"]
y = [40,85,75,35]
z = [20,30,40,15]

width = 0.2
p = np.arange(len(x))
p1 = [j + width for j in p]
plt.title("PARKING SURVEY")
plt.xlabel("vehicles")
plt.ylabel("numbers of vehicles")

plt.xticks(p+width/2, x, rotation = 30)

plt.barh(p,y,color = "r",edgecolor = "black")
plt.barh(p1,z,color = "g",edgecolor = "black")

plt.show()

# %% [markdown]
# MATPLOTLIB - SCATTERED

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5,6]
y = [4,2,3,5,1,8]

plt.title("scatter plot", fontsize = 20)
plt.xlabel("month",fontsize = 20)
plt.ylabel("number", fontsize = 20)

size = [300,150,120,190,80,100]
c = ["red","green","orange","blue","black","purple"]

plt.scatter(x,y, color = c, s = size, alpha = 0.5)
plt.show()

# %%
x = [1,2,3,4,5,6]
y = [4,2,3,5,1,8]

plt.title("scatter plot", fontsize = 20)
plt.xlabel("month",fontsize = 20)
plt.ylabel("number", fontsize = 20)

size = [300,150,120,190,80,100]
c = ["red","green","orange","blue","black","purple"]

plt.scatter(x,y, color = c, s = size, marker = "*", edgecolor = "brown", linewidth = 2 )
plt.show()

# %%
x = [1,2,3,4,5,6]
y = [4,2,3,5,1,8]

plt.title("scatter plot", fontsize = 20)
plt.xlabel("month",fontsize = 20)
plt.ylabel("number", fontsize = 20)

size = [300,150,120,190,80,100]
c = [10,20,30,45,8,99]

plt.scatter(x,y,c = c,s = size, cmap = "Accent")
plt.show()

# %%
x = [1,2,3,4,5,6]
y = [4,2,3,5,1,8]

plt.title("scatter plot", fontsize = 20)
plt.xlabel("month",fontsize = 20)
plt.ylabel("number", fontsize = 20)

size = [300,150,120,190,80,100]
c = [10,20,30,45,8,99]

plt.scatter(x,y,c = c,s = size, cmap = "Dark2")
plt.show()

# %%
x = [1,2,3,4,5,6]
y = [4,2,3,5,1,8]

plt.title("scatter plot", fontsize = 20)
plt.xlabel("month",fontsize = 20)
plt.ylabel("number", fontsize = 20)

size = [300,150,120,190,80,100]
c = [10,20,30,45,8,99]

plt.scatter(x,y,c = c,s = size, cmap = "Dark2")
plt.colorbar()
plt.show()

# %%
x = [1,2,3,4,5,6]
y = [4,2,3,5,1,8]

plt.title("scatter plot", fontsize = 20)
plt.xlabel("month",fontsize = 20)
plt.ylabel("number", fontsize = 20)

size = [300,150,120,190,80,100]
c = [10,20,30,45,8,99]

plt.scatter(x,y,c = c,s = size, cmap = "flag")
plt.colorbar()
plt.show()

# %%
x = [1,2,3,4,5,6]
y = [4,2,3,5,1,8]

plt.title("scatter plot", fontsize = 20)
plt.xlabel("month",fontsize = 20)
plt.ylabel("number", fontsize = 20)

size = [300,150,120,190,80,100]
c = [10,20,30,45,8,99]

plt.scatter(x,y,c = c,s = size, cmap = "prism")
plt.colorbar()
plt.show()

# %%
x = [1,2,3,4,5,6]
y = [4,2,3,5,1,8]

plt.title("scatter plot", fontsize = 20)
plt.xlabel("month",fontsize = 20)
plt.ylabel("number", fontsize = 20)

size = [300,150,120,190,80,100]
c = [10,20,30,45,8,99]

plt.scatter(x,y,c = c,s = size, cmap = "Reds")
plt.colorbar()
plt.show()

# %%
x = [1,2,3,4,5,6]
y = [4,2,3,5,1,8]

plt.title("scatter plot", fontsize = 20)
plt.xlabel("month",fontsize = 20)
plt.ylabel("number", fontsize = 20)

size = [300,150,120,190,80,100]
c = [10,20,30,45,8,99]

plt.scatter(x,y,c = c,s = size, cmap = "winter")
plt.colorbar()
plt.show()

# %%
x = [1,2,3,4,5,6]
y = [4,2,3,5,1,8]

plt.title("scatter plot", fontsize = 20)
plt.xlabel("month",fontsize = 20)
plt.ylabel("number", fontsize = 20)

size = [300,150,120,190,80,100]
c = [10,20,30,45,8,99]

plt.scatter(x,y,c = c,s = size, cmap = "jet")
plt.colorbar()
plt.show()

# %%
x = [1,2,3,4,5,6]
y = [4,2,3,5,1,8]

plt.title("scatter plot", fontsize = 20)
plt.xlabel("month",fontsize = 20)
plt.ylabel("number", fontsize = 20)

size = [300,150,120,190,80,100]
c = [10,20,30,45,8,99]

plt.scatter(x,y,c = c,s = size, cmap = "jet", alpha = 0.4)
plt.colorbar()
plt.show()

# %%
x = [1,2,3,4,5,6]
y = [4,2,3,5,1,8]

plt.title("scatter plot", fontsize = 20)
plt.xlabel("month",fontsize = 20)
plt.ylabel("number", fontsize = 20)

size = [300,150,120,190,80,100]
c = [10,20,30,45,8,99]

plt.scatter(x,y,c = c,s = size, cmap = "Dark2")
t = plt.colorbar()
t.set_label("Colorbar")
plt.show()

# %%
x = [1,2,3,4,5,6]
y = [4,2,3,5,1,8]
z = [10,11,12,13,14,15]

plt.title("scatter plot", fontsize = 20)
plt.xlabel("month",fontsize = 20)
plt.ylabel("number", fontsize = 20)

size = [300,150,120,190,80,100]
c = [10,20,30,45,8,99]

plt.scatter(x,y,c = c,s = size, cmap = "Dark2")
t = plt.colorbar()
t.set_label("Colorbar",fontsize =  15)

plt.scatter(x,z,c = c,s = size, cmap = "Greys")
t = plt.colorbar()
t.set_label("Colorbar",fontsize =  15)


plt.show()

# %% [markdown]
# MATPLOTLIB - HISTOGRAM

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
x = np.random.randint(10,60,(50))
print(x)
# Out:
# [31 36 37 36 36 10 40 32 31 30 33 38 50 11 34 40 12 14 56 33 57 24 38 23
#  43 27 27 16 24 53 52 49 16 49 47 45 27 53 28 10 42 38 55 57 17 22 53 46
#  26 13]

# %%
no = [31, 36, 37, 36, 36, 10, 40, 32, 31, 30, 33, 38, 50, 11, 34, 40, 12, 14, 56, 33, 57, 24, 38, 23,
 43, 27, 27, 16, 24, 53, 52, 49, 16, 49, 47, 45, 27, 53, 28, 10, 42, 38, 55, 57, 17, 22, 53, 46,
 26, 13]

plt.hist(no, color = "g", edgecolor = "black", linewidth = 2)

plt.title("RECORD")
plt.xlabel("python")
plt.ylabel("number")
# Out:
# Text(0, 0.5, 'number')

# %%
no = [31, 36, 37, 36, 36, 10, 40, 32, 31, 30, 33, 38, 50, 11, 34, 40, 12, 14, 56, 33, 57, 24, 38, 23,
 43, 27, 27, 16, 24, 53, 52, 49, 16, 49, 47, 45, 27, 53, 28, 10, 42, 38, 55, 57, 17, 22, 53, 46,
 26, 13]

l = [10,20,30,40,50,60]
plt.hist(no, color = "g", edgecolor = "black", bins =l)

plt.title("RECORD")
plt.xlabel("python")
plt.ylabel("number")

plt.show()

# %%
no = [31, 36, 37, 36, 36, 10, 40, 32, 31, 30, 33, 38, 50, 11, 34, 40, 12, 14, 56, 33, 57, 24, 38, 23,
 43, 27, 27, 16, 24, 53, 52, 49, 16, 49, 47, 45, 27, 53, 28, 10, 42, 38, 55, 57, 17, 22, 53, 46,
 26, 13]

l = [10,20,30,40,50,60]
plt.hist(no,  "auto",(0,100), edgecolor = "black")

plt.title("RECORD")
plt.xlabel("python")
plt.ylabel("number")

plt.show()
# Out:
# C:\Users\Ahmed Ali\AppData\Local\Temp\ipykernel_8264\3009725419.py:6: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(no,  "auto",(0,100), edgecolor = "black")

# %%
no = [31, 36, 37, 36, 36, 10, 40, 32, 31, 30, 33, 38, 50, 11, 34, 40, 12, 14, 56, 33, 57, 24, 38, 23,
 43, 27, 27, 16, 24, 53, 52, 49, 16, 49, 47, 45, 27, 53, 28, 10, 42, 38, 55, 57, 17, 22, 53, 46,
 26, 13]

l = [10,20,30,40,50,60]
plt.hist(no, edgecolor = "black", cumulative = -1)
plt.xlabel("python")

plt.title("RECORD")
plt.ylabel("number")
plt.xlabel("python")


plt.show()

# %%
no = [31, 36, 37, 36, 36, 10, 40, 32, 31, 30, 33, 38, 50, 11, 34, 40, 12, 14, 56, 33, 57, 24, 38, 23,
 43, 27, 27, 16, 24, 53, 52, 49, 16, 49, 47, 45, 27, 53, 28, 10, 42, 38, 55, 57, 17, 22, 53, 46,
 26, 13]

l = [10,20,30,40,50,60]
plt.hist(no,color = "g", edgecolor = "black",bottom = 10)
plt.xlabel("python")

plt.title("RECORD")
plt.ylabel("number")
plt.xlabel("python")


plt.show()

# %%
no = [31, 36, 37, 36, 36, 10, 40, 32, 31, 30, 33, 38, 50, 11, 34, 40, 12, 14, 56, 33, 57, 24, 38, 23,
 43, 27, 27, 16, 24, 53, 52, 49, 16, 49, 47, 45, 27, 53, 28, 10, 42, 38, 55, 57, 17, 22, 53, 46,
 26, 13]

l = [10,20,30,40,50,60]
plt.hist(no,color = "g", edgecolor = "black", align = "left")
plt.xlabel("python")

plt.title("RECORD")
plt.ylabel("number")
plt.xlabel("python")


plt.show()

# %%
no = [31, 36, 37, 36, 36, 10, 40, 32, 31, 30, 33, 38, 50, 11, 34, 40, 12, 14, 56, 33, 57, 24, 38, 23,
 43, 27, 27, 16, 24, 53, 52, 49, 16, 49, 47, 45, 27, 53, 28, 10, 42, 38, 55, 57, 17, 22, 53, 46,
 26, 13]

l = [10,20,30,40,50,60]
plt.hist(no,color = "g", edgecolor = "black",histtype = "step")
plt.xlabel("python")

plt.title("RECORD")
plt.ylabel("number")
plt.xlabel("python")


plt.show()

# %%
no = [31, 36, 37, 36, 36, 10, 40, 32, 31, 30, 33, 38, 50, 11, 34, 40, 12, 14, 56, 33, 57, 24, 38, 23,
 43, 27, 27, 16, 24, 53, 52, 49, 16, 49, 47, 45, 27, 53, 28, 10, 42, 38, 55, 57, 17, 22, 53, 46,
 26, 13]

l = [10,20,30,40,50,60]
plt.hist(no,color = "black", edgecolor = "black",histtype = "stepfilled")
plt.xlabel("python")

plt.title("RECORD")
plt.ylabel("number")
plt.xlabel("python")


plt.show()

# %%
no = [31, 36, 37, 36, 36, 10, 40, 32, 31, 30, 33, 38, 50, 11, 34, 40, 12, 14, 56, 33, 57, 24, 38, 23,
 43, 27, 27, 16, 24, 53, 52, 49, 16, 49, 47, 45, 27, 53, 28, 10, 42, 38, 55, 57, 17, 22, 53, 46,
 26, 13]

l = [10,20,30,40,50,60]
plt.hist(no,color = "white", edgecolor = "black",histtype = "barstacked", orientation = "horizontal")
plt.xlabel("python")

plt.title("RECORD")
plt.ylabel("number")
plt.xlabel("python")


plt.show()

# %%
no = [31, 36, 37, 36, 36, 10, 40, 32, 31, 30, 33, 38, 50, 11, 34, 40, 12, 14, 56, 33, 57, 24, 38, 23,
 43, 27, 27, 16, 24, 53, 52, 49, 16, 49, 47, 45, 27, 53, 28, 10, 42, 38, 55, 57, 17, 22, 53, 46,
 26, 13]

l = [10,20,30,40,50,60]
plt.hist(no,color = "white", edgecolor = "black",histtype = "barstacked",rwidth = 0.5)
plt.xlabel("python")

plt.title("RECORD")
plt.ylabel("number")
plt.xlabel("python")


plt.show()

# %%
no = [31, 36, 37, 36, 36, 10, 40, 32, 31, 30, 33, 38, 50, 11, 34, 40, 12, 14, 56, 33, 57, 24, 38, 23,
 43, 27, 27, 16, 24, 53, 52, 49, 16, 49, 47, 45, 27, 53, 28, 10, 42, 38, 55, 57, 17, 22, 53, 46,
 26, 13]

l = [10,20,30,40,50,60]
plt.hist(no,color = "white", edgecolor = "black",histtype = "barstacked",log = True)
plt.xlabel("python")

plt.title("RECORD")
plt.ylabel("number")
plt.xlabel("python")


plt.show()

# %%
no = [31, 36, 37, 36, 36, 10, 40, 32, 31, 30, 33, 38, 50, 11, 34, 40, 12, 14, 56, 33, 57, 24, 38, 23,
 43, 27, 27, 16, 24, 53, 52, 49, 16, 49, 47, 45, 27, 53, 28, 10, 42, 38, 55, 57, 17, 22, 53, 46,
 26, 13]

l = [10,20,30,40,50,60]
plt.hist(no,color = "white", edgecolor = "black",histtype = "barstacked", label = "CODE")
plt.xlabel("python")

plt.title("RECORD")
plt.ylabel("number")
plt.xlabel("python")
plt.legend()

plt.show()

# %%
no = [31, 36, 37, 36, 36, 10, 40, 32, 31, 30, 33, 38, 50, 11, 34, 40, 12, 14, 56, 33, 57, 24, 38, 23,
 43, 27, 27, 16, 24, 53, 52, 49, 16, 49, 47, 45, 27, 53, 28, 10, 42, 38, 55, 57, 17, 22, 53, 46,
 26, 13]

l = [10,20,30,40,50,60]
plt.hist(no,color = "white", edgecolor = "black", label = "CODE")
plt.xlabel("python")

plt.title("RECORD")
plt.ylabel("number")
plt.xlabel("python")
plt.legend()

plt.axvline(33.5, color = "magenta")

plt.show()

# %%
no = [31, 36, 37, 36, 36, 10, 40, 32, 31, 30, 33, 38, 50, 11, 34, 40, 12, 14, 56, 33, 57, 24, 38, 23,
 43, 27, 27, 16, 24, 53, 52, 49, 16, 49, 47, 45, 27, 53, 28, 10, 42, 38, 55, 57, 17, 22, 53, 46,
 26, 13]

l = [10,20,30,40,50,60]
plt.hist(no,color = "white", edgecolor = "black", label = "CODE")
plt.xlabel("python")

plt.title("RECORD")
plt.ylabel("number")
plt.xlabel("python")
plt.legend()

plt.axvline(33.5, color = "magenta",label = "seperate")
plt.legend()

plt.show()

# %%
no = [31, 36, 37, 36, 36, 10, 40, 32, 31, 30, 33, 38, 50, 11, 34, 40, 12, 14, 56, 33, 57, 24, 38, 23,
 43, 27, 27, 16, 24, 53, 52, 49, 16, 49, 47, 45, 27, 53, 28, 10, 42, 38, 55, 57, 17, 22, 53, 46,
 26, 13]

l = [10,20,30,40,50,60]
plt.hist(no,color = "white", edgecolor = "black", label = "CODE")
plt.xlabel("python")

plt.title("RECORD")
plt.ylabel("number")
plt.xlabel("python")
plt.legend()

plt.axvline(33.5, color = "magenta",label = "seperate")
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# MATPLOTLIB - PIECHART

# %%
import matplotlib.pyplot as plt

# %%
x = [10,20,30,40]
y = ["english","physics","maths","chemistry"]

plt.pie(x)
plt.show()

# %%
x = [10,20,30,40]
y = ["english","physics","maths","chemistry"]

plt.pie(x, labels = y)
plt.show()

# %%
x = [10,20,30,40]
y = ["english","physics","maths","chemistry"]
ex = [0.0,0.2,0.0,0.0]


plt.pie(x, labels = y, explode = ex)
plt.show()

# %%
x = [10,20,30,40]
y = ["english","physics","maths","chemistry"]
ex = [0.2,0.2,0.2,0.2]


plt.pie(x, labels = y, explode = ex)
plt.show()

# %%
x = [10,20,30,40]
y = ["english","physics","maths","chemistry"]

c = ["blue","green","aqua","magenta"]

plt.pie(x, labels = y, colors = c )
plt.show()

# %%
x = [10,20,30,40]
y = ["english","physics","maths","chemistry"]


plt.pie(x, labels = y, autopct = "%0.1f%%")
plt.show()

# %%
x = [10,20,30,40]
y = ["english","physics","maths","chemistry"]


plt.pie(x, labels = y, autopct = "%0.2f%%", shadow = True )
plt.show()

# %%
x = [10,20,30,40]
y = ["english","physics","maths","chemistry"]


plt.pie(x, labels = y, autopct = "%0.2f%%", shadow = True , radius = 0.5 )
plt.show()

# %%
x = [10,20,30,40]
y = ["english","physics","maths","chemistry"]


plt.pie(x, labels = y, autopct = "%0.2f%%", shadow = True ,labeldistance = 1.5)
plt.show()

# %%
x = [10,20,30,40]
y = ["english","physics","maths","chemistry"]


plt.pie(x, labels = y, autopct = "%0.2f%%", shadow = True , startangle = 90 )
plt.show()

# %%
x = [10,20,30,40]
y = ["english","physics","maths","chemistry"]


plt.pie(x, labels = y, autopct = "%0.2f%%", shadow = True , textprops = {"fontsize":20} )
plt.show()

# %%
x = [10,20,30,40]
y = ["english","physics","maths","chemistry"]


plt.pie(x, labels = y, autopct = "%0.2f%%", shadow = True , counterclock = False)
plt.show()

# %%
x = [10,20,30,40]
y = ["english","physics","maths","chemistry"]

ex = [0.0,0.2,0.0,0.0]


plt.pie(x, labels = y, shadow = True,explode = ex, wedgeprops = {"linewidth":4}  )
plt.show()

# %%
x = [10,20,30,40]
y = ["english","physics","maths","chemistry"]

ex = [0.0,0.2,0.0,0.0]


plt.pie(x, labels = y, shadow = True,explode = ex, wedgeprops = {"linewidth":4, "edgecolor":"black" })
plt.show()

# %%
x = [10,20,30,40]
y = ["english","physics","maths","chemistry"]

ex = [0.0,0.2,0.0,0.0]


plt.pie(x, labels = y, shadow = True, rotatelabels = True  )
plt.show()

# %%
x = [10,20,30,40]
y = ["english","physics","maths","chemistry"]


plt.pie(x, labels = y, shadow = True,)

plt.title("SUBJECT ANALYSIS")
plt.legend(loc = 10)
plt.show()

# %%
plt.pie([1])
plt.show()

# %%
x = [10,20,30,40]
y = ["english","physics","maths","chemistry"]
x1 = [5,15,25,35]

c= ["yellow","magenta","aqua","grey"]
plt.pie(x, labels = y, radius = 1.5)
plt.pie(x1, labels = y, radius = 0.5,colors = c)

    

plt.show()

# %%
x = [10,20,30,40]
y = ["english","physics","maths","chemistry"]
x1 = [5,15,25,35]

c= ["yellow","magenta","aqua","grey"]
plt.pie(x, labels = y, radius = 1.5)
plt.pie([1], colors = "w")

    

plt.show()

# %%
x = [10,20,30,40]
y = ["english","physics","maths","chemistry"]
x1 = [5,15,25,35]

c= ["yellow","magenta","aqua","grey"]
plt.pie(x, labels = y, radius = 1.5)
cr = plt.Circle(xy=(0,0), radius = 1, facecolor = "w")
plt.gca().add_artist(cr)
    

plt.show()

# %% [markdown]
# MATPLOTLIB - STEMPLOT

# %%
x = [1,2,3,4,5,6]
y = [2,4,6,8,2,1]

plt.stem(x,y)
plt.show()

# %%
x = [1,2,3,4,5,6]
y = [2,4,6,8,2,1]

plt.stem(x,y, linefmt  = ":")
plt.show()

# %%
x = [1,2,3,4,5,6]
y = [2,4,6,8,2,1]

plt.stem(x,y, linefmt  = ":", markerfmt = "g+")
plt.show()

# %%
x = [1,2,3,4,5,6]
y = [2,4,6,8,2,1]

plt.stem(x,y, linefmt  = ":", markerfmt = "g+",bottom = 2)
plt.show()

# %%
x = [1,2,3,4,5,6]
y = [2,4,6,8,2,1]

plt.stem(x,y, linefmt  = ":", markerfmt = "go",basefmt ="g")
plt.show()

# %%
x = [1,2,3,4,5,6]
y = [2,4,6,8,2,1]

plt.stem(x,y, linefmt  = ":", markerfmt = "go",basefmt ="g",label = "CODE")
plt.legend()
plt.show()

# %%
x = [1,2,3,4,5,6]
y = [2,4,6,8,2,1]

plt.stem(x,y, linefmt  = ":", markerfmt = "go",basefmt ="g",label = "CODE", use_line_collection = False)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 x = [1,2,3,4,5,6]
#       2 y = [2,4,6,8,2,1]
# ----> 4 plt.stem(x,y, linefmt  = ":", markerfmt = "go",basefmt ="g",label = "CODE", use_line_collection = False)
#       5 plt.legend()
#       6 plt.show()
#
# TypeError: stem() got an unexpected keyword argument 'use_line_collection'

# %%
x = [1,2,3,4,5,6]
y = [2,4,6,8,2,1]

plt.stem(x,y, linefmt  = ":", markerfmt = "go",basefmt ="g",label = "CODE", orientation = "horizontal")
plt.legend()
plt.show()

# %% [markdown]
# MATPLOTLIB - WHISKER PLOT

# %%
import matplotlib.pyplot as plt

# %%
x = [10,20,30,40,50,60,70]
plt.boxplot(x)
plt.show()

# %%
x = [10,20,30,40,50,60,70]
plt.boxplot(x, notch = True)
plt.show()

# %%
x = [10,20,30,40,50,60,70]
plt.boxplot(x, vert = False)
plt.show()

# %%
x = [10,20,30,40,50,60,70]
plt.boxplot(x, vert = True)
plt.show()

# %%
x = [10,20,30,40,50,60,70]
plt.boxplot(x, widths = 0.4)
plt.show()

# %%
x = [10,20,30,40,50,60,70]
plt.boxplot(x, labels = ["CODE"])
plt.show()
# Out:
# C:\Users\Ahmed Ali\AppData\Local\Temp\ipykernel_11524\661243969.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(x, labels = ["CODE"])

# %%
x = [10,20,30,40,50,60,70]
plt.boxplot(x, labels = ["CODE"], patch_artist = True)
plt.show()
# Out:
# C:\Users\Ahmed Ali\AppData\Local\Temp\ipykernel_11524\2974523659.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(x, labels = ["CODE"], patch_artist = True)

# %%
x = [10,20,30,40,50,60,70]
plt.boxplot(x, labels = ["CODE"],  showmeans = True)
plt.show()
# Out:
# C:\Users\Ahmed Ali\AppData\Local\Temp\ipykernel_11524\1785250605.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(x, labels = ["CODE"],  showmeans = True)

# %%
x = [10,15,3,40,25,60,70,130,150]
plt.boxplot(x, labels = ["CODE"],  showmeans = True)
plt.show()
# Out:
# C:\Users\Ahmed Ali\AppData\Local\Temp\ipykernel_11524\2616880627.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(x, labels = ["CODE"],  showmeans = True)

# %%
x = [10,20,30,40,50,60,70]
plt.boxplot(x, labels = ["CODE"],  showmeans = True, whis = 2)
plt.show()
# Out:
# C:\Users\Ahmed Ali\AppData\Local\Temp\ipykernel_11524\3379150050.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(x, labels = ["CODE"],  showmeans = True, whis = 2)

# %%
x = [10,20,30,40,50,60,70,130,150]
plt.boxplot(x, labels = ["CODE"],  showmeans = True, sym = "g+")
plt.show()
# Out:
# C:\Users\Ahmed Ali\AppData\Local\Temp\ipykernel_11524\3072758055.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(x, labels = ["CODE"],  showmeans = True, sym = "g+")

# %%
x = [10,20,30,40,50,60,70,130,150]
plt.boxplot(x, labels = ["CODE"],  showmeans = True, boxprops = dict(color = "r"))
plt.show()
# Out:
# C:\Users\Ahmed Ali\AppData\Local\Temp\ipykernel_11524\277145222.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(x, labels = ["CODE"],  showmeans = True, boxprops = dict(color = "r"))

# %%
x = [10,20,30,40,50,60,70,130,150]
plt.boxplot(x, labels = ["CODE"],  showmeans = True, boxprops = dict(color = "r"),capprops = dict(color = "magenta"))
plt.show()
# Out:
# C:\Users\Ahmed Ali\AppData\Local\Temp\ipykernel_11524\1670838439.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(x, labels = ["CODE"],  showmeans = True, boxprops = dict(color = "r"),capprops = dict(color = "magenta"))

# %%
x = [10,20,30,40,50,60,70,130,150]
plt.boxplot(x, labels = ["CODE"],  showmeans = True, boxprops = dict(color = "r"),capprops = dict(color = "magenta"), whiskerprops = dict(color = "blue"))
plt.show()
# Out:
# C:\Users\Ahmed Ali\AppData\Local\Temp\ipykernel_11524\143694780.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(x, labels = ["CODE"],  showmeans = True, boxprops = dict(color = "r"),capprops = dict(color = "magenta"), whiskerprops = dict(color = "blue"))

# %%
x = [10,20,30,40,50,60,70,130,150]
plt.boxplot(x, labels = ["CODE"],  showmeans = True, boxprops = dict(color = "r"),capprops = dict(color = "magenta"), whiskerprops = dict(color = "blue"),
           flierprops = dict(markeredgecolor = "g"))
plt.show()
# Out:
# C:\Users\Ahmed Ali\AppData\Local\Temp\ipykernel_11524\1244778012.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(x, labels = ["CODE"],  showmeans = True, boxprops = dict(color = "r"),capprops = dict(color = "magenta"), whiskerprops = dict(color = "blue"),

# %%
x = [10,20,30,40,50,60,70,130,150]
x1 = [10,20,30,40,50,60,70,80,130]

y = [x,x1]
plt.boxplot(y, labels = ["CODE","CHERRY"],  showmeans = True, boxprops = dict(color = "r"),capprops = dict(color = "magenta"), whiskerprops = dict(color = "blue"),
           flierprops = dict(markeredgecolor = "g"))
plt.show()
# Out:
# C:\Users\Ahmed Ali\AppData\Local\Temp\ipykernel_11524\1441518334.py:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(y, labels = ["CODE","CHERRY"],  showmeans = True, boxprops = dict(color = "r"),capprops = dict(color = "magenta"), whiskerprops = dict(color = "blue"),

# %%
x = [10,20,30,40,50,60,70,130,150]
x1 = [10,20,30,40,50,60,70,80,130]
x2 = [23,45,67,89,98,76,54,33,21]

y = [x,x1,x2]
plt.boxplot(y, labels = ["CODE","CHERRY","ORANGE"],  showmeans = True, boxprops = dict(color = "r"),capprops = dict(color = "magenta"), whiskerprops = dict(color = "blue"),
           flierprops = dict(markeredgecolor = "g"))
plt.show()
# Out:
# C:\Users\Ahmed Ali\AppData\Local\Temp\ipykernel_11524\1741386529.py:6: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(y, labels = ["CODE","CHERRY","ORANGE"],  showmeans = True, boxprops = dict(color = "r"),capprops = dict(color = "magenta"), whiskerprops = dict(color = "blue"),

# %% [markdown]
# AREASTOCK PLOT

# %%
x = [1,2,3,4,5]
area = [1,2,3,4,5]
plt.stackplot(x,area)
plt.show()

# %%
x = [1,2,3,4,5]
area = [2,5,3,4,1]
plt.stackplot(x,area)
plt.show()

# %%
x = [1,2,3,4,5]
area = [2,5,3,4,1]
area2 = [1,2,3,4,2]
area3 = [4,1,5,2,3]

plt.stackplot(x,area,area2,area3)
plt.show()

# %%
x = [1,2,3,4,5]
area1 = [2,5,3,4,1]
area2 = [1,2,3,4,2]
area3 = [4,1,5,2,3]

l = ["area1","area2","area3"]

plt.stackplot(x,area1,area2,area3,labels = l)
plt.legend()
plt.show()

# %%
x = [1,2,3,4,5]
area1 = [2,5,3,4,1]
area2 = [1,2,3,4,2]
area3 = [4,1,5,2,3]

l = ["area1","area2","area3"]

plt.stackplot(x,area1,area2,area3,labels = l,colors =["r","g","b","a"])
plt.legend()
plt.show()

# %%
x = [1,2,3,4,5]
area1 = [2,5,3,4,1]
area2 = [1,2,3,4,2]
area3 = [4,1,5,2,3]

l = ["area1","area2","area3"]

plt.stackplot(x,area1,area2,area3,labels = l,colors =["r","g","b"], baseline = "sym")
plt.legend()
plt.show()

# %%
x = [1,2,3,4,5]
area1 = [2,5,3,4,1]
area2 = [1,2,3,4,2]
area3 = [4,1,5,2,3]

l = ["area1","area2","area3"]

plt.stackplot(x,area1,area2,area3,labels = l,colors =["r","g","b"], baseline = "wiggle")
plt.legend(loc = 1)
plt.show()

# %%
x = [1,2,3,4,5]
area1 = [2,5,3,4,1]
area2 = [1,2,3,4,2]
area3 = [4,1,5,2,3]

l = ["area1","area2","area3"]

plt.stackplot(x,area1,area2,area3,labels = l,colors =["r","g","b"], baseline = "wiggle")
plt.title("GRAPH",fontsize = 20)
plt.xlabel("x axis",fontsize = 20)
plt.ylabel("y axis",fontsize = 20)

plt.grid()

plt.legend(loc = 1)
plt.show()

# %% [markdown]
# STEP PLOT

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [1,2,3,4,5]

plt.step(x,y)
plt.show()

# %%
x = [1,2,3,4,5]
y = [5,3,2,1,4]

plt.step(x,y)
plt.show()

# %%
x = [1,2,3,4,5]
y = [1,2,3,4,5]

plt.step(x,y)

plt.title("GRAPH",fontsize = 20)

plt.xlabel("x  axis",fontsize =  20)
plt.ylabel("y axis",fontsize = 20)

plt.grid()
plt.show()

# %%
x = [1,2,3,4,5]
y = [1,2,3,4,5]

plt.step(x,y,color = "r")

plt.title("GRAPH",fontsize = 20)
plt.xlabel("x  axis",fontsize =  20)
plt.ylabel("y axis",fontsize = 20)

plt.grid()
plt.show()

# %%
x = [1,2,3,4,5]
y = [5,3,2,1,4]

plt.step(x,y,color = "g", marker = "o",ms = 10)

plt.title("GRAPH",fontsize = 20)
plt.xlabel("x  axis",fontsize =  20)
plt.ylabel("y axis",fontsize = 20)

plt.grid()
plt.show()

# %%
x = [1,2,3,4,5]
y = [5,3,2,1,4]

plt.step(x,y,color = "g", marker = "o",ms = 10, mfc = "black")

plt.title("GRAPH",fontsize = 20)
plt.xlabel("x  axis",fontsize =  20)
plt.ylabel("y axis",fontsize = 20)

plt.grid()
plt.show()

# %%
x = [1,2,3,4,5]
y = [5,3,2,1,4]

plt.step(x,y,color = "g", marker = "o",ms = 10, mfc = "black",label = "price")



plt.title("GRAPH",fontsize = 20)
plt.xlabel("x  axis",fontsize =  20)
plt.ylabel("y axis",fontsize = 20)

plt.legend(loc = 4)
plt.grid()
plt.show()

# %% [markdown]
# FILLED BETWEEN PLOT

# %%
x = [1,2,3,4,5]
y = [1,2,3,4,5]

plt.plot(x,y,color = "g")
plt.fill_between(x,y)
plt.title("GRAPH")
plt.xlabel("x axis")
plt.ylabel("y axis")

plt.show()

# %%
x = [1,2,3,4,5]
y = [1,2,3,4,5]

plt.plot(x,y,color = "g")
plt.fill_between(x=[2,4],y1=2,y2=4)
plt.title("GRAPH")
plt.xlabel("x axis")
plt.ylabel("y axis")

plt.show()

# %%
import numpy as np
x = np.array([1,2,3,4,5])
y = np.array([1,2,3,4,5])

plt.plot(x,y,color = "g")
plt.fill_between(x,y , where =(x>=3) & (x<=4.5))
plt.title("GRAPH")
plt.xlabel("x axis")
plt.ylabel("y axis")

plt.show()

# %%
import numpy as np
x = np.array([1,2,3,4,5])
y = np.array([1,2,3,4,5])

plt.plot(x,y,color = "g")
plt.fill_between(x,y , where =(x>=3) & (x<=4.5), alpha = 0.4)
plt.title("GRAPH")
plt.xlabel("x axis")
plt.ylabel("y axis")

plt.show()

# %% [markdown]
# SUBPLOT

# %%
x = [1,2,3,4]
y = [1,2,3,4]
plt.subplot(2,2,1)
plt.plot(x,y,color="r")

x1 = [1,2,3,4,5]
y1 = [2,3,5,1,4]
plt.subplot(2,2,2)
plt.step(x,y)

x3 = [10,20,30,40]
plt.subplot(2,2,3)
plt.pie(x3)


x4 = ["a","b","c","d"]
y4 = [2,3,4,5]
plt.subplot(2,2,4)
plt.bar(x4,y4)

plt.show()

# %%
x = [1,2,3,4]
y = [1,2,3,4]
plt.subplot(3,3,1)
plt.plot(x,y,color="r")

x1 = [1,2,3,4,5]
y1 = [2,3,5,1,4]
plt.subplot(3,3,2)
plt.step(x,y)

x3 = [10,20,30,40]
plt.subplot(3,3,3)
plt.pie(x3)


x4 = ["a","b","c","d"]
y4 = [2,3,4,5]
plt.subplot(3,3,4)
plt.bar(x4,y4)

plt.show()

# %% [markdown]
# SAVEFIG

# %%
x = [1,2,3,4,]
y = [1,2,3,4]

plt.plot(x,y)
plt.title("GRAPH")
plt.xlabel("day")
plt.ylabel("number")

plt.savefig("code2", dpi = 2000)

plt.show()

# %%
x = [1,2,3,4,]
y = [1,2,3,4]

plt.plot(x,y)
plt.title("GRAPH")
plt.xlabel("day")
plt.ylabel("number")

plt.savefig("code4.pdf", facecolor = "g")

plt.show()

# %%
x = [1,2,3,4,]
y = [1,2,3,4]

plt.plot(x,y)
plt.title("GRAPH")
plt.xlabel("day")
plt.ylabel("number")

plt.savefig("code4.jpg", facecolor = "g")

plt.show()

# %%
x = [1,2,3,4,]
y = [1,2,3,4]

plt.plot(x,y)
plt.title("GRAPH")
plt.xlabel("day")
plt.ylabel("number")

plt.savefig("code7.pdf", facecolor = "g",transparent = True,bbox_inches = "tight")

plt.show()

# %% [markdown]
# AXIS IN MATPLOTLIB

# %%
x = [1,2,3,4,5]
y = [2,4,5,1,3]

plt.plot(x,y)
plt.show()

# %%
x = [1,2,3,4,5]
y = [2,4,5,1,3]

plt.plot(x,y)
plt.xticks(x)
plt.yticks(y)

plt.show()

# %%
x = [1,2,3,4,5]
y = [2,4,5,1,3]

plt.plot(x,y)
plt.xlim(0,20)
plt.ylim(0,20)


plt.show()

# %%
x = [1,2,3,4,5]
y = [2,4,5,1,3]

plt.plot(x,y)
plt.axis([0,10,0,7])
    
plt.show()

# %%
x = [1,2,3,4,5]
y = [2,4,5,1,3]

plt.plot(x,y)
plt.title("GROWTH GRAPH")
plt.text(2,4,"apple")

plt.show()

# %%
x = [1,2,3,4,5]
y = [2,4,5,1,3]

plt.plot(x,y)
plt.text(2,4,"apple", fontsize = 15,style= "italic")

plt.show()

# %%
x = [1,2,3,4,5]
y = [2,4,5,1,3]

plt.plot(x,y)
plt.text(2,4,"apple", fontsize = 15,style= "italic", bbox = {"facecolor" : "r"})

plt.show()

# %%
x = [1,2,3,4,5]
y = [2,4,5,1,3]

plt.plot(x,y)
plt.text(2,4,"apple", fontsize = 15,style= "italic", bbox = {"facecolor" : "r"})
plt.annotate("student",xy = (2,1), xytext = (4,4), arrowprops = dict(facecolor = "g",shrink = 100))

plt.show()
